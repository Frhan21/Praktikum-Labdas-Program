# %% [markdown]
# <a href="https://colab.research.google.com/github/Frhan21/Praktikum-Labdas-Program/blob/main/Penyelesaian_Modul_M9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 



print(f'''
{'='*50}
Program ini akan menyelesaikan data - data dari 
   Percobaan Gerak Benda Menggelinding (M9)
{'='*50 }''')

print(f'''{'-'*50}
1. Percobaan Momen Inersia Silinder Pejal
{'-'*50}''')

# Data dari Silinder
m = 0.412
d = 0.08
r = d/2
g = 9.8

# Data Praktikum
teta = np.array([5,10,15,20,25,30])
a = np.array([0.601,1.155,1.699,1.934,2.829,3.386])
sinteta = np.sin(np.radians(teta))
I = (m*(r**2)/a)*(g*np.sin(np.radians(teta))-a)
n = len(a)

# Jumlah (Ip - Irata2)**2
Irata = sum(I)/n
IR= sum((I-Irata)**2)

# Nilai ralat2 nyaa
RM = (IR/(n-1))**(1/2)
RN = (RM/Irata)*100

# Nilai Inersia Teori 
Ite = 1/2*(m*(r**2))
Rel = (abs(Ite-Irata)/Ite)*100


# Plotting ke dalam tabel 
print(f'''Dengan 
massa silinder = {m} kg , 
jari - jari silinder = {r} m 
''')
data = {
    'teta':teta,
    'sin teta':sinteta,
    'Percepatan':a,
    'Momen Iner':I,
    '(Ipr - I rata2)^2':(I-(sum(I)/len(teta))**2)
}
pd.set_option('display.float_format', lambda x: '%.3e' % x)
df = pd.DataFrame(data)
print(df)
print(f'''{'-'*50}
Rata - rata I praktikum = {sum(I)/len(teta):.3e} kg m2
Jumlah (Ip - Irata2)^2  = {IR:.3e} kg m2 
Ralat Mutlak (RM)       = {RM:.3e} 
Ralat Nisbi  (RN)       = {RN:.3f} %
{'-'*50}
Kesalahan Relatif (%)   = {Rel:.3f} %
''')
print(f'''{'-'*50}
2. Percobaan Momen Inersia Silinder Berongga 
{'-'*50}''')
# Data dari Silinder
m = 0.499
ddal = 0.075
dlua = 0.065
rdal = ddal/2
rlua = dlua/2
g = 9.8

# Data Praktikum
teta = np.array([5,10,15,20,25,30])
a = np.array([0.470,0.957,1.371,2.001,2.666,2.689])
sinteta = np.sin(np.radians(teta))
I = (m*(rdal**2+rlua**2)/a)*(g*np.sin(np.radians(teta))-a)
n = len(a)

# Jumlah (Ip - Irata2)**2
Irata = sum(I)/n
IR= sum((I-Irata)**2)

# Nilai ralat2 nyaa
RM = (IR/(n-1))**(1/2)
RN = (RM/Irata)*100

# Nilai Inersia Teori 
Ite = 1/2*(m*((rdal**2)+(rlua**2)))
Rel = (abs(Ite-Irata)/Ite)*100


# Plotting ke dalam tabel 
print(f'''Dengan 
massa silinder = {m} kg , 
jari - jari dalam = {rdal} m, 
jari - jari luar = {rlua}m
''')
data = {
    'teta':teta,
    'sin teta':sinteta,
    'Percepatan':a,
    'Momen Iner':I,
    '(Ipr - I rata2)^2':(I-(sum(I)/len(teta))**2)
}
pd.set_option('display.float_format', lambda x: '%.3e' % x)
df = pd.DataFrame(data)
print(df)
print(f'''{'-'*50}
Rata - rata I praktikum = {sum(I)/len(teta):.3e} kg m2
Jumlah (Ip - Irata2)^2  = {IR:.3e} kg m2 
Ralat Mutlak (RM)       = {RM:.3e} 
Ralat Nisbi  (RN)       = {RN:.3f} %
{'-'*50}
Momen Inersia Teori     = {Ite:.3e} kg m2 
Kesalahan Relatif (%)   = {Rel:.3f} %
''')
# Out:
# ==================================================
# Program ini akan menyelesaikan data - data dari
#    Percobaan Gerak Benda Menggelinding (M9)
# ==================================================
# --------------------------------------------------
# 1. Percobaan Momen Inersia Silinder Pejal
# --------------------------------------------------
# Dengan
# massa silinder = 0.412 kg ,
# jari - jari silinder = 0.04 m
#
#    teta  sin teta  Percepatan  Momen Iner  (Ipr - I rata2)^2
# 0     5 8.716e-02   6.010e-01   2.776e-04          2.775e-04
# 1    10 1.736e-01   1.155e+00   3.121e-04          3.119e-04
# 2    15 2.588e-01   1.699e+00   3.249e-04          3.248e-04
# 3    20 3.420e-01   1.934e+00   4.833e-04          4.831e-04
# 4    25 4.226e-01   2.829e+00   3.059e-04          3.058e-04
# 5    30 5.000e-01   3.386e+00   2.948e-04          2.946e-04
# --------------------------------------------------
# Rata - rata I praktikum = 3.331e-04 kg m2
# Jumlah (Ip - Irata2)^2  = 2.834e-08 kg m2
# Ralat Mutlak (RM)       = 7.529e-05
# Ralat Nisbi  (RN)       = 22.605 %
# --------------------------------------------------
# Kesalahan Relatif (%)   = 1.056 %
#
# --------------------------------------------------
# 2. Percobaan Momen Inersia Silinder Berongga
# --------------------------------------------------
# Dengan
# massa silinder = 0.499 kg ,
# jari - jari dalam = 0.0375 m,
# jari - jari luar = 0.0325m
#
#    teta  sin teta  Percepatan  Momen Iner  (Ipr - I rata2)^2
# 0     5 8.716e-02   4.700e-01   1.004e-03          1.003e-03
# 1    10 1.736e-01   9.570e-01   9.563e-04          9.554e-04
# 2    15 2.588e-01   1.371e+00   1.045e-03          1.044e-03
# 3    20 3.420e-01   2.001e+00   8.295e-04          8.287e-04
# 4    25 4.226e-01   2.666e+00   6.801e-04          6.793e-04
# 5    30 5.000e-01   2.689e+00   1.010e-03          1.010e-03
# --------------------------------------------------
# Rata - rata I praktikum = 9.208e-04 kg m2
# Jumlah (Ip - Irata2)^2  = 9.781e-08 kg m2
# Ralat Mutlak (RM)       = 1.399e-04
# Ralat Nisbi  (RN)       = 15.188 %
# --------------------------------------------------
# Momen Inersia Teori     = 6.144e-04 kg m2
# Kesalahan Relatif (%)   = 49.879 %
